# %% [markdown]
# Here I Tested the Finnhub Stock API: https://finnhub.io

# %% [markdown]
# Source: https://www.columbia.edu/~tmd2142/best-6-stock-market-apis-for-2020.html
#
# Coverage: Stock API with Global markets (60+ stock exchanges) data, forex, crypto
#
# Historical market data coverage: 20+ years EOD , intraday data
#
# Tick data: 20 years
#
# Fundamental data: Global coverage of Company profile, 30+ years of financial statements, AnalystÃ¢â‚¬â„¢s price target and recommendation, EPS/Sale surprises.
#
# Alternative data: Earnings call transcripts, global M&A data
#
# Stock API Access: REST API and Websocket
#
# Pricing : Free plan comes with 60 API calls/minute
#
# Comment: Institutional-grade data with the most generous free plan. Finnhub is the most comprehensive instituional-grade stock API available for retail investors at this point.

# %% [markdown]
# # Setup and Imports

# %%
pip install --no-cache-dir -r ../requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install websocket-client
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install finnhub-python
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import finnhub
import pandas as pd
import websocket

# %% [markdown]
# # Finnhub API Tests

# %%
# setup api key and client (get it from https://finnhub.io/)
api_key= "d0b4411r01qo0h63eokgd0b4411r01qo0h63eol0"

finnhub_client = finnhub.Client(api_key=api_key)

# %% [markdown]
# c
# Current price
#
# d
# Change
#
# d
# Percent change
#
# h
# High price of the day
#
# l
# Low price of the day
#
# o
# Open price of the day
#
# pc
# Previous close price

# %%
#Stock price quote:
finnhub_client.quote('AAPL')
# Out:
# {'c': 205.35,
#  'd': -7.97,
#  'dp': -3.7362,
#  'h': 206.99,
#  'l': 202.16,
#  'o': 206.09,
#  'pc': 213.32,
#  't': 1746216000}

# %% [markdown]
# Test von Github

# %%
# Basic Financials
finnhub_client.company_basic_financials('AAPL', 'all')
# Out:
# {'metric': {'10DayAverageTradingVolume': 52.44148,
#   '13WeekPriceReturnDaily': -13.5696,
#   '26WeekPriceReturnDaily': -10.9381,
#   '3MonthADReturnStd': 49.93237,
#   '3MonthAverageTradingVolume': 58.88728,
#   '52WeekHigh': 260.1,
#   '52WeekHighDate': '2024-12-26',
#   '52WeekLow': 169.11,
#   '52WeekLowDate': '2024-05-01',
#   '52WeekPriceReturnDaily': 21.2936,
#   '5DayPriceReturnDaily': -2.2794,
#   'assetTurnoverAnnual': 1.0714,
#   'assetTurnoverTTM': 1.1673,
#   'beta': 1.263012,
#   'bookValuePerShareAnnual': 3.7673,
#   'bookValuePerShareQuarterly': 4.4712,
#   'bookValueShareGrowth5Y': -5.85,
#   'capexCagr5Y': -2.08,
#   'cashFlowPerShareAnnual': 7.1978,
#   'cashFlowPerShareQuarterly': 6.5924,
#   'cashFlowPerShareTTM': 6.86253,
#   'cashPerSharePerShareAnnual': 4.3112,
#   'cashPerSharePerShareQuarterly': 3.2463,
#   'currentDividendYieldTTM': 0.4961,
#   'currentEv/freeCashFlowAnnual': 29.0097,
#   'currentEv/freeCashFlowTTM': 32.0498,
# ...

# %%
# Fetch basic financials for AAPL and TSLA
res_aapl = finnhub_client.company_basic_financials('AAPL', 'all')
res_tsla = finnhub_client.company_basic_financials('TSLA', 'all')

# Convert both results to DataFrames
df_aapl = pd.DataFrame(res_aapl)
df_tsla = pd.DataFrame(res_tsla)

# Combine the two DataFrames
df = pd.concat([df_aapl, df_tsla], ignore_index=False)

# Display the combined DataFrame
df.head(10)
# Out:
#                                 metric metricType series symbol
# 10DayAverageTradingVolume     52.44148        all    NaN   AAPL
# 13WeekPriceReturnDaily        -13.5696        all    NaN   AAPL
# 26WeekPriceReturnDaily        -10.9381        all    NaN   AAPL
# 3MonthADReturnStd             49.93237        all    NaN   AAPL
# 3MonthAverageTradingVolume    58.88728        all    NaN   AAPL
# 52WeekHigh                       260.1        all    NaN   AAPL
# 52WeekHighDate              2024-12-26        all    NaN   AAPL
# 52WeekLow                       169.11        all    NaN   AAPL
# 52WeekLowDate               2024-05-01        all    NaN   AAPL
# 52WeekPriceReturnDaily         21.2936        all    NaN   AAPL

# %%
df.columns
# Out:
# Index(['metric', 'metricType', 'series', 'symbol'], dtype='object')

# %%
df_new=df.T
df_new.head(10)
# Out:
#            10DayAverageTradingVolume 13WeekPriceReturnDaily  \
# metric                      52.44148               -13.5696
# metricType                       all                    all
# series                           NaN                    NaN
# symbol                          AAPL                   AAPL
#
#            26WeekPriceReturnDaily 3MonthADReturnStd  \
# metric                   -10.9381          49.93237
# metricType                    all               all
# series                        NaN               NaN
# symbol                       AAPL              AAPL
#
#            3MonthAverageTradingVolume 52WeekHigh 52WeekHighDate 52WeekLow  \
# metric                       58.88728      260.1     2024-12-26    169.11
# metricType                        all        all            all       all
# series                            NaN        NaN            NaN       NaN
# symbol                           AAPL       AAPL           AAPL      AAPL
#
# ...

# %%
# Market News
finnhub_client = finnhub.Client(api_key="d0b3sghr01qo0h63em6gd0b3sghr01qo0h63em70")

finnhub_client.general_news('general', min_id=0)
# Out:
# [{'category': 'top news',
#   'datetime': 1746285840,
#   'headline': 'Here’s what I’ve learned after writing about Apple, Intel and Silicon Valley for over 30 years',
#   'id': 7477910,
#   'image': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/market_watch_logo.png',
#   'related': '',
#   'source': 'MarketWatch',
#   'summary': 'History repeats itself in Silicon Valley, a few wacky stories are worth remembering and AI is getting creepier every day.',
#   'url': 'https://www.marketwatch.com/story/heres-what-ive-learned-after-writing-about-apple-intel-and-silicon-valley-for-over-30-years-605ea0a0'},
#  {'category': 'top news',
#   'datetime': 1746280801,
#   'headline': "Brain health experts' top 3 tips for lowering your risk of dementia, stroke and depression—all at the same time",
#   'id': 7477904,
#   'image': 'https://image.cnbcfm.com/api/v1/image/108139413-1746115053824-gettyimages-1886164052-weight_10_0000.jpeg?v=1746115126&w=1920&h=1080',
#   'related': '',
# ...
